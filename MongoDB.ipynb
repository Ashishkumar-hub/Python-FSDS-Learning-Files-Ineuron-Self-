# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)

# %%
pip install pymongo[srv]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# ...

# %%
#establishing connectivity with mongodb Atlas 
import pymongo
client_atlas = pymongo.MongoClient("mongodb+srv://Ashish:mongodb@cluster0.lpxyy.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client_atlas.test

# %%
#establishing connectivity with mongodb compass localhost  
DEFAULT_CONNECTION_URL = "mongodb://localhost:27017/"
DB_NAME = "iNeuron"

# Establish a connection with mongoDB
client_compass = pymongo.MongoClient(DEFAULT_CONNECTION_URL)

# Create a DB
dataBase = client_compass[DB_NAME]

# %%
client_atlas.list_database_names() #database names in mongodb atlas
# Out:
# ['iNeuron', 'admin', 'local']

# %%
client_compass.list_database_names() #database names in mongodb compass
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-33-c3f6d0c93668> in <module>
# ----> 1 client_compass.list_database_names() #database names in mongodb compass
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in list_database_names(self, session)
#    1703
#    1704                 try:
# -> 1705                     sock_info.send_message(msg, 0)
#    1706                 except Exception as exc:
#    1707                     if publish:
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in list_databases(self, session, **kwargs)
#    1684             db = coll = "OP_KILL_CURSORS"
#    1685
# -> 1686         spec = SON([('killCursors', coll), ('cursors', cursor_ids)])
#    1687         with server.get_socket(self.__all_credentials) as sock_info:
#    1688             if sock_info.max_wire_version >= 4 and namespace is not None:
#
# ...

# %%
#create a ollection until it is cretaed database that hass been created will not be shown in compass 
COLLECTION_NAME = "iNeuron_Products"
collection = dataBase[COLLECTION_NAME]

# %%
# verifying whether we have our database in the list or not 
# we'll use the following function:-

def checkExistence_COL(COLLECTION_NAME, DB_NAME, db):
    """It verifies the existence of collection name in a database"""
    collection_list = db.list_collection_names()
    
    if COLLECTION_NAME in collection_list:
        print(f"Collection:'{COLLECTION_NAME}' in Database:'{DB_NAME}' exists")
        return True
    
    print(f"Collection:'{COLLECTION_NAME}' in Database:'{DB_NAME}' does not exists OR \n\
    no documents are present in the collection")
    return False

_ = checkExistence_COL(COLLECTION_NAME=COLLECTION_NAME, DB_NAME=DB_NAME, db=dataBase)

# %%
#Insert a record in the collection
record = {'companyName': 'iNeuron',
         'product': 'Affordable AI',
         'courseOffered': 'Deep Learning for Computer Vision',
         'name' : ["ashish","kumar",12350],
         "record_dict" :{"name" :"ashish" , "mail_id" : "singh.ashish.kr96@gmail.com","ph_number" :789456123}}

collection.insert_one(record)

# %%
#Insert a record in the collection
record = {'companyName': 'learning product',
         'product': 'AI',
         'courseOffered': 'ML',
         'name' : ["ashish","kumar",12350],
         "record_dict" :{"name" :"ashish" , "mail_id" : "singh.ashish.kr96@gmail.com","ph_number" :789456123}}

collection.insert_one(record)

# %%
#creating database and inserting records in mongodb atlas  
import pymongo
client_atlas = pymongo.MongoClient("mongodb+srv://Ashish:mongodb@cluster0.lpxyy.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client_atlas["iNeuron"]
#create a ollection until it is cretaed database that hass been created will not be shown in compass 
COLLECTION_NAME = "iNeuron_Products"
collection_atlas = db[COLLECTION_NAME]

# %%
#Insert a record in the collection
record = {'companyName': 'iNeuron',
         'product': 'Affordable AI',
         'courseOffered': 'Deep Learning for Computer Vision',
         'name' : ["ashish","kumar",12350],
         "record_dict" :{"name" :"ashish" , "mail_id" : "singh.ashish.kr96@gmail.com","ph_number" :789456123}}

collection_atlas.insert_one(record)

# %%
#inserting multiple records in mongodb atlas
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program',
     'test' : 'ffsdfsffsf',
     'complex' : [{"name" : "ashish", "list" : [1,2,3,4,5]},{"mail_id" : "singh.ashish.kr96@gmail.com"},{"phone_no":789456123},[1,2,3]]
    }]
    
rec = collection_atlas.insert_many(list_of_records)

# %%
# the unique ID that of the record that we have inserted -
inserted_IDs = rec.inserted_ids

for idx, unique_ids in enumerate(inserted_IDs):
    print(f"{idx}. {unique_ids}")

# %%
COLLECTION_NAME = "iNeuron_Faculties"
client_atlas = db[COLLECTION_NAME]

list_of_records_user_defined_id = [
    {"_id": "2288",
    "companyName": "iNeuron",
    "Faculty": "ashish Kumar"},
    {"_id": "8229",
    "companyName": "iNeuron",
    "Faculty": "Sagar"},
]

faculties_record = client_atlas.insert_many(list_of_records_user_defined_id)

# %%
for i in client_atlas.find():
    print(i)

# %%
COLLECTION_NAME = "iNeuron_Faculty"
faculty = db[COLLECTION_NAME]

list_of_records_user_defined_id = [
    {"_id": "828",
    "companyName": "iNeuron",
    "Faculty": "ashish Kumar"},
    {"_id": "289",
    "companyName": "iNeuron",
    "Faculty": "Sagar"},
    {"companyName": "iNeuron",
    "Faculty": "Sagar"}
]

faculties_record = faculty.insert_many(list_of_records_user_defined_id)

# %%
for i in faculty.find():
    print(i)

# %%
for i in faculty.find({"Faculty":"ashish Kumar"}):
    print(i)

# %%
# find all the record at once present in thr record with all the fields
all_record = collection_atlas.find()

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")

# %%
for i in faculty.find({'_id':{'$gt':'61f0fa4360d71c80560b1a9a'}}):
    print(i)

# %%
#other commands can also be used there are many commands as per need to full fill the requirements as per demand 
faculty.

# %%
client_atlas.list_database_names() #database names in mongodb atlas
# Out:
# ['iNeuron', 'admin', 'local']

# %%
client_atlas.get_default_database()
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.lpxyy.mongodb.net:27017', 'cluster0-shard-00-02.lpxyy.mongodb.net:27017', 'cluster0-shard-00-00.lpxyy.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-gwa6lu-shard-0', tls=True), 'myFirstDatabase')

# %%
client_atlas.topology_description
# Out:
# <TopologyDescription id: 61f11b99453e850d0c84b13f, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('cluster0-shard-00-00.lpxyy.mongodb.net', 27017) server_type: RSSecondary, rtt: 0.031125774627483168>, <ServerDescription ('cluster0-shard-00-01.lpxyy.mongodb.net', 27017) server_type: RSSecondary, rtt: 0.032860068186805924>, <ServerDescription ('cluster0-shard-00-02.lpxyy.mongodb.net', 27017) server_type: RSPrimary, rtt: 0.03232149426686956>]>

# %%
db.list_collection_names()
# Out:
# []

# %%
#creating database and inserting records in mongodb atlas  
import pymongo
client_atlas = pymongo.MongoClient("mongodb+srv://Ashish:mongodb@cluster0.lpxyy.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# %%
db = client_atlas
# Out:
#   File "<ipython-input-3-b6da437d6492>", line 1
#     db = client_atlas[]
#                       ^
# SyntaxError: invalid syntax

# %%
import pymongo
client_atlas = pymongo.MongoClient("mongodb+srv://Ashish:mongodb@cluster0.lpxyy.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# %%
db = client_atlas.get_database("ashish")

# %%
records = db.ashish_records

# %%
records.count_documents({})
# Out:
# 0

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://Ashish:mongodb@cluster0.lpxyy.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test

# %%
db = client.get_database("ashish")

# %%
records = db.ashishdb_records

# %%
records.count_documents({}) #it should show the number of documens that are present inside the database cluster still showing 0
#still i am able to alter the dtaase to enter records
# Out:
# 0

# %%
COLLECTION_NAME = "ashishdb"
ashish = db[COLLECTION_NAME]

list_of_records_user_defined_id = [
    {"_id": "828",
    "companyName": "iNeuron",
    "Faculty": "ashish Kumar"},
    {"_id": "289",
    "companyName": "iNeuron",
    "Faculty": "Sagar"},
    {"companyName": "iNeuron",
    "Faculty": "Sagar"}
]

ashish_record = ashish.insert_many(list_of_records_user_defined_id)

# %% [markdown]
# ![Screenshot%20%2874%29.png](attachment:Screenshot%20%2874%29.png)
