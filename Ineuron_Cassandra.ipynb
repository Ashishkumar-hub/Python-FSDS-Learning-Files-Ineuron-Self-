# %%
pip install cassandra-driver
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ymongo (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\dell\anaconda3\lib\site-packages)
# ...

# %%
import cassandra
print(cassandra.__version__)
# Out:
# 3.25.0

# %% [markdown]
# #### Go to organisation settings for generating token

# %% [markdown]
# ![Screenshot%20%2880%29.png](attachment:Screenshot%20%2880%29.png)

# %% [markdown]
# #####  Generating token for  client id and client secret as per privilage you wanna provide to use and share the client id and client secret to coonect to database to that user

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# #####  Download the bundle from here and then secure the conection bundle
# ##### Note: While dwnloading the bundle click on the specified programming language here PYTHON is used

# %% [markdown]
# ![Screenshot%20%2881%29.png](attachment:Screenshot%20%2881%29.png)

# %% [markdown]
# ##### Access the code to connect to database with help of connect option

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

cloud_config= {
        'secure_connect_bundle': 'E:\\secure-connect-ashish-db.zip'
}
#here enter the client id and client secret copy the code from python 
auth_provider = PlainTextAuthProvider('WPZJwQiHJmxrCsvpPtprrKsf', '-PA.WZtP8ZAiJp6g-qNfCCojmQFIHzUPsUdST3GeNPfmUXKoExd_5h6056ZUKqjLZaXpNG28YcgQNj8MR9PFeUezsncu2r,JmWL_XKrIuS.1cTOS2bCwjUTRrnsU-.Ao')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("select release_version from system.local").one()
if row:
    print(row[0])
else:
    print("An error occurred.")
# Out:
# 4.0.0.6816

# %%
# create keyspace in database manually in cloud and then use keyspace from jupyter notebook
row = session.execute("use ashish_db_ineuron;")

# %%
try:
    row=session.execute("use ashish_db_ineuron;")
except Exception as e:
    print(e)

# %%
#creating table in the keyspace
row=session.execute("CREATE TABLE Members(id int PRIMARY KEY, name text, age int, height int);")

# %% [markdown]
# ##### Once connection is made and keyscape is created manually or through here if permission is granted then only keyspace can be made from here else by admin user manually on dashboard at cassandra online space provided by DATA STAX ASTRA

# %% [markdown]
# #### Now Shoot your queries

# %%
#inserting into table
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (1,'Ashish',25,165);")

# %%
#inserting multiple records in database ashish_db on keyspace ashish ashish_db_ineuron
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (2,'shubham',26,165);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (3,'aradhana',25,142);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (4,'rakesh',55,157);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (5,'poonam',52,145);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (6,'seema',30,145);")

# %%
#view the data in table
row=session.execute("select * from Members;")
for i in row:
    print(i)
# Out:
# Row(id=5, age=52, height=145, name='poonam')
# Row(id=1, age=25, height=165, name='Ashish')
# Row(id=2, age=26, height=165, name='shubham')
# Row(id=4, age=55, height=157, name='rakesh')
# Row(id=6, age=30, height=145, name='seema')
# Row(id=3, age=25, height=142, name='aradhana')

# %%
#not inserting value in some column (not providing age)
row=session.execute("INSERT INTO Members(id,name,age) VALUES (7,'sakshi',32);")

# %%
#view the data in table 
row=session.execute("select * from Members;")
for i in row:
    print(i)
#null where data not given
# Out:
# Row(id=5, age=52, height=145, name='poonam')
# Row(id=1, age=25, height=165, name='Ashish')
# Row(id=2, age=26, height=165, name='shubham')
# Row(id=4, age=55, height=157, name='rakesh')
# Row(id=7, age=32, height=None, name='sakshi')
# Row(id=6, age=30, height=145, name='seema')
# Row(id=3, age=25, height=142, name='aradhana')

# %%
#alter existing table (adding more columns to table)
row=session.execute("ALTER TABLE Members ADD email varchar;")

# %%
row=session.execute("select * from Members;")
for i in row:
    print(i)
# Out:
# Row(id=5, age=52, email=None, height=145, name='poonam')
# Row(id=1, age=25, email=None, height=165, name='Ashish')
# Row(id=2, age=26, email=None, height=165, name='shubham')
# Row(id=4, age=55, email=None, height=157, name='rakesh')
# Row(id=7, age=32, email=None, height=None, name='sakshi')
# Row(id=6, age=30, email=None, height=145, name='seema')
# Row(id=3, age=25, email=None, height=142, name='aradhana')

# %%
#creating table in the keyspace
row=session.execute("CREATE TABLE Ashish(id int PRIMARY KEY, name text, age int, height int);")

# %%
#dropping the table
row=session.execute("DROP TABLE if exists Ashish;")

# %%
#truncating (removing all data from table)
row=session.execute("TRUNCATE Members;")

# %%
#table is empty now
for i in row:
    print(i)
#OUtput: No records to print

# %%
#INSERING DATA AGAIN
row=session.execute("INSERT INTO Members(id,name,age,height,email) VALUES (2,'shubham',26,165,'memohit@gmail.com');")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (3,'aradhana',25,142);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (4,'rakesh',55,157);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (5,'poonam',52,145);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (6,'seema',30,145);")

# %%
#truncating (removing all data from table)
row=session.execute("TRUNCATE Members;")

# %%
#INSERING DATA AGAIN
row=session.execute("INSERT INTO Members(id,name,age,height,email) VALUES (1,'Ashish',26,165,'singh.ashish.kr96@gmail.com');")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (2,'aradhana',25,142);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (3,'rakesh',55,157);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (4,'poonam',52,145);")
row=session.execute("INSERT INTO Members(id,name,age,height) VALUES (5,'seema',30,145);")

# %%
row=session.execute("select * from Members;")
for i in row:
    print(i)
# Out:
# Row(id=5, age=30, email=None, height=145, name='seema')
# Row(id=1, age=26, email='singh.ashish.kr96@gmail.com', height=165, name='Ashish')
# Row(id=2, age=25, email=None, height=142, name='aradhana')
# Row(id=4, age=52, email=None, height=145, name='poonam')
# Row(id=3, age=55, email=None, height=157, name='rakesh')

# %%
#update existing table 
row=session.execute("UPDATE ashish_db_ineuron.Members SET name= 'Ashish Kumar Singh',age = 26 WHERE id=1;")

# %%
row=session.execute("select * from Members;")
for i in row:
    print(i)
# Out:
# Row(id=5, age=30, email=None, height=145, name='seema')
# Row(id=1, age=26, email='singh.ashish.kr96@gmail.com', height=165, name='Ashish Kumar Singh')
# Row(id=2, age=25, email=None, height=142, name='aradhana')
# Row(id=4, age=52, email=None, height=145, name='poonam')
# Row(id=3, age=55, email=None, height=157, name='rakesh')

# %%
#delete a particular row or a part of row
row=session.execute("DELETE age FROM Members WHERE id=3;")

# %%
row=session.execute("select * from Members;")
for i in row:
    print(i)
# Out:
# Row(id=5, age=30, email=None, height=145, name='seema')
# Row(id=1, age=26, email='singh.ashish.kr96@gmail.com', height=165, name='Ashish Kumar Singh')
# Row(id=2, age=25, email=None, height=142, name='aradhana')
# Row(id=4, age=52, email=None, height=145, name='poonam')
# Row(id=3, age=None, email=None, height=157, name='rakesh')

# %%
#selecting particular data
row=session.execute("SELECT name, age FROM Members WHERE id = 1;")

# %%
for i in row:
    print(i)
# Out:
# Row(name='Ashish Kumar Singh', age=26)

# %% [markdown]
# #### OUTPUT at CQL Console in cassandra dtabase that we have created

# %% [markdown]
# ![Screenshot%20%2879%29.png](attachment:Screenshot%20%2879%29.png)

# %% [markdown]
# ![Screenshot%20%2878%29.png](attachment:Screenshot%20%2878%29.png)

# %% [markdown]
# ![Screenshot%20%2877%29.png](attachment:Screenshot%20%2877%29.png)

# %% [markdown]
# Requirements:
#
#     1: JAVA (set path in environment)
#     2. Download cassandra zip file and then place it in drive and create environment
#     Note: Check in CLI wih commands :
#             java -version
#             echo %HOME_JAVA%
#             echo %HOME_CASSANDRA%
#     3. Apache Thrift from oracle
#     4. python version to be specified in CLI while creating environment
#
# ##### FOR CONNECTING TO LOCAL SYSYTEM

# %%
# FOR CONNECTING TO LOCAL SYSYTEM
from cassandra.cluster import Cluster
#from cassandra.auth import PlainTextAuthProvider

#cloud_config= {'secure_connect_bundle':r'C:\Users\Admin\Downloads\secure-connect-test.zip'}
#auth_provider = PlainTextAuthProvider('xbCLnGiTgbFemYjnNKyXmdJk', 'uZQFsScneNQ8+WhqNmLehyRXNZ4HZ233ktFIw1fkCulK,czUQ7hGkJJze4lzHU2Mcl7vOMm56,7sQJYiFLIUwQzjw4BEeWufXeaMC8vG1exmzGaoQ+glmBLW8+48tIAd')
cluster = Cluster()
session = cluster.connect()

row = session.execute("select release_version from system.local")
print(row)
